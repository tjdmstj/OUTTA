# %% [markdown]
# # 라이브러리 설치

# %%
pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.10.0-py3-none-any.whl (6.7 MB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /opt/homebrew/lib/python3.11/site-packages (from selenium) (1.26.15)
# Collecting trio~=0.17 (from selenium)
#   Using cached trio-0.22.2-py3-none-any.whl (400 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Using cached trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/homebrew/lib/python3.11/site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=20.1.0 in /opt/homebrew/lib/python3.11/site-packages (from trio~=0.17->selenium) (23.1.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Collecting exceptiongroup (from trio-websocket~=0.9->selenium)
#   Using cached exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting PySocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sortedcontainers, PySocks, outcome, h11, exceptiongroup, wsproto, trio, trio-websocket, selenium
# Successfully installed PySocks-1.7.1 exceptiongroup-1.1.2 h11-0.14.0 outcome-1.2.0 selenium-4.10.0 sortedcontainers-2.4.0 trio-0.22.2 trio-websocket-0.10.3 wsproto-1.2.0
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Selenium 연습

# %%
pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Downloading webdriver_manager-3.9.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from webdriver_manager) (2.29.0)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from webdriver_manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->webdriver_manager) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->webdriver_manager) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->webdriver_manager) (2022.12.7)
# Installing collected packages: python-dotenv, webdriver_manager
# Successfully installed python-dotenv-1.0.0 webdriver_manager-3.9.1
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## By.Name 구문

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()

# 지마켓의 메인 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr')

# 검색어를 입력할 수 있는 input 요소를 찾습니다.
search_box = driver.find_element(By.NAME, 'keyword')

# 검색어를 입력하고, Enter 키를 눌러 검색을 실행합니다.
search_box.send_keys('손풍기')
search_box.send_keys(Keys.RETURN)

# 작업이 끝나면 WebDriver를 종료하여 브라우저 창을 닫습니다.
driver.quit()

# %% [markdown]
# ## By.CSS_SELECTOR 구문

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

title_list = list()

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()

# 지마켓의 베스트 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr/n/best')

# 상품명을 입력 받아 item_list 변수에 저장합니다.
item_list = driver.find_elements(By.CSS_SELECTOR, 'a.itemname')

for item in item_list:
    title_list.append(item.text)

driver.quit()

# %%
print(title_list)
# Out:
# ['[원할머니]원할머니 명품육개장 600g 10팩', '삼다수 T 제주 삼다수 무라벨 500ml X 40병', '이쌀이다 촉촉하고 찰진 안동밥상 백진주 10kg', '[삼립]삼립디저트 누네띠네 2.5kgx1개', '[풀무원]풀무원 풀무원 T 노엣지피자 4종 6판 골라담기 (콤비/베이컨/포테이토콘/BBQ)', '[서울우유]서울우유 멸균우유 흰우유 200mlx48개', '다향 훈제오리 13팩 1등급', '[해동찬가]7/24(월) 단하루 20%할인) 한돈대패삼겹살 300gX4팩+한돈대패목살 300gX3팩 /총 7팩(2.1kg)', '[동아오츠카]나랑드사이다 제로 345ml 24캔(뚱캔)', '[할리스]할리스 1L 아메리카노 x4병', '[디스커버리](롯데백화점)디스커버리 공용 마운틴 LT DXSH4112N', '궁중비법 포기김치 10kg', '[코카콜라]코카콜라 190ml x 60CAN', '나비골 국내산 여름별미 열무김치 2kg 2개구매시비빔면증정(주문일자7월24일 기준으로 증정)', '프리미엄 1등급 한우 등심 200g x 2팩 /총 400g /17560원(쿠폰가)/냉장 한우 암소', '(15%쿠폰적용가 8670) 냄새줄인 락스 2100ml x 6개 / 최신제조 / 욕실 및 화장실 살균 소독제', '[동아오츠카]동아오츠카 T 라인바싸 탄산수/탄산음료 500ml 2박스 ( 20입+20입 )', '[목우촌]목우촌주부9단 살코기햄 1kg x 2개', '[코디](15%+클럽12% 쿠폰적용가 25700) 블루 3겹 데코 화장지 27m 30롤 3팩 휴지', '[도루코](최종혜택가 23800원) 페이스6 면도기획세트 2호(면도기+날 총13입+폼) + 6스타일 날2입 증정 / 6중날', '[메가박스](유니버스클럽 전용) 메가박스 일반예매권 2D-주중/주말', '[목우촌]목우촌 주부9단 비엔나소시지 450g x 3개', '무중력 깔창 1+1+1+1 신발 쿠션 충격흡수 완화 군인 등산 구두 푹신한 키높이', '(할인특가/별똥별 신간) 생각의 발견 (도서10권+워크북3권) / 세이펜 미포함', '[동아출판]동아출판 큐브수학 (연산/개념/개념응용/실력/심화 선택구매) - 2권이상무배', '[목우촌]T 목우촌 프라임 한입 돈까스 500g x4봉', '[델포유]델포유 오븐에 구운 십센치 파운드 30개 5가지맛', '제로스킨 스키니매트 (1+1)', '[스카이패션](1+1) 남녀공용 시원한 린넨라이크 쿨 와이드 밴딩팬츠', '[하비비](15%쿠폰) 청개구리 자동 변기 클리너 세정제 6개 (12개월분)', '제로스킨 케이스 시그니처5 (1+1)', '[더푸룸]섬유유연제 라벤더향 2.5L 4개 (특가행사)', '[엘렌실라](7/24 단하루)(1+1+정품증정) 슈퍼 달팽이크림 50g 1+1 (+프렌치콜라겐 대용량 에멀전 750
� 포기김치 8kg(신세계푸드 중복쿠폰 할인)', '[구글플레이]기프트코드 10만원 / 구글 기프트카드', '[목우촌]목우촌 프라임 한입 돈까스 500g x4봉', '[풀무원]G풀무원 토이쿠키 3+1 브레드이발소/킹덤 3개 구매시 1개 더', '[노브랜드]노브랜드 도톰한 물티슈 100매 X 20개입', '[신세계푸드]밀크앤허니 파운드/롤/카스테라 6종 1+1 골라담기 (신세계푸드 중복쿠폰 할인)', '프리미엄 1등급 한우 채끝 200g x 2팩 총 400g /20080원(쿠폰가)/ 냉장 한우 암소', '[벨롭]밸롭 아쿠아슈즈/워터슈즈/래쉬가드/수영복/비치웨어/여성/남성/아동/키즈 모음전', '[대상 웰라이프][최종혜택가22,760원] 마이밀 뉴프로틴 오리지널 24입 +증정', '[맥심]맥심 모카골드 커피믹스 400T', '[대상 웰라이프]뉴케어 구수한맛 200ml x 30팩 /균형영양식 가장 친숙한 맛 누룽지맛 식사대용식 환자영양식', '[바스파]스크럽 사해소금 바디워시/클렌저 각질케어 1000ml 쿠폰가13180 (+행사중)', '[HC해피콜]NEW 컴포트 다이아몬드 후라이팬 2종세트 (28팬+28웍) + 스타벅스 기프티콘 증정', '[아토세이프]최종혜택가 14520원 아토세이프 귀찮아 습기제거제 520ml 24개입/제습제/장마철필수품', '[구글플레이]기프트코드 5만원 / 구글 기프트카드', '[깨끗한나라]깨끗한나라 순수시그니처 화장지 브라운 30m 30롤 2팩', '[BBQ]BBQ 비비큐치킨 공식몰 / 자메이카 통다리 바베큐 x 10팩 / 오늘만 시즈닝 증정', '[샤오미]최종48만 미지아 1S B116 올인원 물걸레 로봇청소기 (관부가세 포함)', '[동원샘물]동원샘물 2L 24병 /생수전문배송', '[스파클]스파클생수 500ml 100병 (도착보장/무라벨생수)', '제로스킨 핸드폰필름 아틀라스 갤럭시', '[올반키친]올반 찰핫도그15봉+크런치핫도그15봉(신세계푸드 중복쿠폰 할인)', '[코카콜라]코카콜라 업소용 500ml 24입', '[헬로]헬로 순수 3겹 30m 30롤 3팩 천연펄프 화장지 초특가행사', '(놀이대전) 캐리비안베이 골드1 골드2 종일권(이용기간 상이)', '[롯데제과]아이스브레이커스 듀오체리 8개 (반값특가)', '[햇반]햇반 210g x24입', '[동원에프앤비]라이트스탠다드 참치 85g x  ...

# %% [markdown]
# # selenium 실행하고 상품명, 가격, 별점 정보 저장

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

title_list = list()
price_list = list()
star_list = list()

# ChromeDriver의 경로를 지정하고, WebDriver 인스턴스를 생성합니다.
driver = webdriver.Chrome()

# 지마켓의 메인 페이지를 엽니다.
driver.get('https://www.gmarket.co.kr')

# 검색어를 입력할 수 있는 input 요소를 찾습니다.
search_box = driver.find_element(By.NAME, 'keyword')

# 검색어를 입력하고, Enter 키를 눌러 검색을 실행합니다.
search_box.send_keys('손풍기')
search_box.send_keys(Keys.RETURN)

# 결과 페이지가 로드될 때까지 잠시 기다립니다.
driver.implicitly_wait(3)

# 정보를 담은 박스를 선택합니다.
search_results = driver.find_elements(By.CSS_SELECTOR, 'div.box__information')

for result in search_results:
    #만족도가 없을 수도 있기에 try except문을 활용
    try:
        title_element = result.find_element(By.CSS_SELECTOR, 'span.text__item')
        price_element = result.find_element(By.CSS_SELECTOR, 'div.box__price-seller > strong')
        star_element = result.find_element(By.CSS_SELECTOR, 'span.image__awards-points > span')
        title_list.append(title_element.text)
        price_list.append(price_element.text)
        star_list.append(star_element.text)
    except:
        pass
    
# 작업이 끝나면 WebDriver를 종료하여 브라우저 창을 닫습니다.
driver.quit()

# %%
title_list
# Out:
# ['초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기',
#  '쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기',
#  '1+1 초특가 무선 선풍기 휴대용 손 선풍기 미니 손풍기 힐템',
#  '슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200',
#  '비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh',
#  '이지마켓 초강력미니선풍기 미니 손선풍기 에어컨손풍기 얼음이 내손안에 핸디써큘레이터',
#  '휴대용 냉각 선풍기 쿨링 핸디팬 다크그레이',
#  'LOOC 룩 휴대용 선풍기 미니 손 핸디형 손풍기 - 블랙',
#  '휴대용 아이스 냉각 미니 손선풍기 딥브라운',
#  '급속냉각 각도조절 핸디선풍기 휴대용 냉각손선풍기',
#  '휴대용 쿨링마사지 급속냉각 에어컨 휴대용 손 선풍기 IW-C500 핑크',
#  '휴대용 선풍기 미니 핸디 6단계 IW-F901 화이트',
#  'BLDC모터 미니 손 핸디 휴대용 선풍기 손풍기 USB C타입',
#  '쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기',
#  '오아 반디팬 미니 무선 휴대용 초경량 저소음 핸디 손 선풍기',
#  '초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기',
#  '윈드프로 휴대용 미니 선풍기 무선 목걸이 탁상용 손선풍기 사무실 책상용 무소음 저소음 USB 손풍기 소형',
#  '머레이 3초 급속냉각 각도조절 에어컨 핸디선풍기 cool-10 (화이트/네이비) 미니 휴대용 에어컨 선풍기',
#  '핸드팬 대용량 2600mAh 충전식 휴대용선풍기 화이트',
#  '시원 3in1 미니 베어 휴대용 손 선풍기 핑크',
#  '휴대용 에어컨 핸디 선풍기 3초 급속냉각 각도조절 COOL-10',
#  '오아 반디팬 미니 무선 휴대용 초경량 저소음 핸디 손 선풍기',
#  '넥풍기 목풍기 넥밴드 선풍기 목에거는 휴대용 OKPOS',
#  '1+1 휴대용 넥밴드 목 선풍기 목걸이 여름 목풍기 KC인증',
#  'BLDC 접이식 리모컨 충전식 무선 미니 휴대용 캠핑용 탁상용 스탠드 선풍기 NFP-03A / 스마일배송',
#  '1+1 휴대용 넥밴드 목 선풍기 목걸이 여름 목풍기 KC인증',
#  '아이스 급속냉각 넥밴드 휴대용 선풍기 네이비',
#  '대우 캠핑용 무선 선풍기 12형 휴대용 전용가방 포함 v1200',
#  '아이스 급속냉각 넥밴드 휴대용 선풍기 화이트',
#  '휴대용 미니 선풍기 무선 탁상용 써큘레이터형 스탠드',
#  '모노 탁상용 무선 휴대용 선풍기 3세대 1+1(할인 행사)',
#  '1+1 탁상용 휴대용 선풍기_FAN190 /화이트+그레이',
#  'BLDC 접이식 리모컨 충전식 무선 미니 휴대용 캠핑용 탁상용 스탠드 선풍기 NFP-03A / 스마일배송',
#  '(혜택가 32.940원) 탁상용 휴대용 선풍기_FAN190 /화이트+화이트',
#  '비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh',
#  '넥풍기 목풍기 넥밴드 선풍기 목에거는 휴대용 OKPOS',
#  '휴대용 넥밴드 선풍기 넥 목 목걸이 목풍기 BI-N
선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (블랙)',
#  '휴대용 넥밴드 선풍기 넥 목 목걸이 목풍기 BI-NF2 화이트',
#  '1+1 휴대용 넥밴드 목 선풍기 목걸이 여름 목풍기 KC인증',
#  '벌레 모기 퇴치 가능한 LED무드등 휴대용 무선 캠핑선풍기 크루카',
#  '오아 라운드 멀티팬 무선 다용도 휴대용 USB 미니 무소음 선풍기',
#  '최신형 LED 넥밴드선풍기 목풍기 휴대용선풍기 5color',
#  '휴대용 탁상용 선풍기 무선선풍기 캠핑선풍기 카이팬',
#  '바쿨 좌우분리 목선풍기 휴대용 넥밴드 선풍기 목에거는 목풍기',
#  '핸드선풍기 휴대용 무소음 BLDC 얼음 냉각 에어컨 쿨링패드 1초 급속냉각 미니 손 선풍기 EDI-8282',
#  '1+1(2개) 핸드선풍기 휴대용 무소음 BLDC 1초 급속냉각 미니 손 선풍기 EDI-8282',
#  '윈드프로 휴대용 미니 선풍기 무선 목걸이 탁상용 손선풍기 사무실 책상용 무소음 저소음 USB 손풍기 소형',
#  '휴대용 넥밴드 선풍기 USB 충전식 넥선풍기 F41화이트',
#  '무선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (화이트)',
#  '휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙',
#  '휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린',
#  '무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1',
#  '엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W']

# %%
price_list
# Out:
# ['29,900',
#  '14,900',
#  '34,900',
#  '45,900',
#  '29,900',
#  '29,900',
#  '27,900',
#  '15,900',
#  '29,900',
#  '37,900',
#  '29,900',
#  '23,650',
#  '13,000',
#  '14,900',
#  '14,900',
#  '29,900',
#  '22,900',
#  '37,900',
#  '14,000',
#  '17,500',
#  '37,900',
#  '14,900',
#  '21,900',
#  '26,900',
#  '39,900',
#  '26,900',
#  '46,900',
#  '118,990',
#  '46,900',
#  '26,900',
#  '29,900',
#  '36,600',
#  '39,900',
#  '36,600',
#  '29,900',
#  '21,900',
#  '17,810',
#  '36,600',
#  '26,900',
#  '26,800',
#  '22,680',
#  '19,900',
#  '118,990',
#  '27,900',
#  '26,900',
#  '37,900',
#  '148,000',
#  '28,410',
#  '26,500',
#  '29,900',
#  '34,900',
#  '139,000',
#  '26,800',
#  '15,900',
#  '26,800',
#  '29,900',
#  '27,900',
#  '43,900',
#  '49,900',
#  '89,000',
#  '26,900',
#  '16,900',
#  '24,900',
#  '15,900',
#  '17,900',
#  '149,000',
#  '38,900',
#  '44,900',
#  '15,900',
#  '29,900',
#  '66,500',
#  '27,310',
#  '39,800',
#  '25,900',
#  '18,910',
#  '36,900',
#  '13,800',
#  '35,900',
#  '29,900',
#  '19,900',
#  '16,800',
#  '29,800',
#  '26,900',
#  '69,000',
#  '27,900',
#  '13,000',
#  '24,610',
#  '28,900',
#  '32,900',
#  '59,800',
#  '22,900',
#  '26,500',
#  '16,800',
#  '33,060',
#  '22,500',
#  '46,800',
#  '24,800']

# %%
star_list
# Out:
# ['',
#  '',
#  '',
#  '만족도 76% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 70% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 76% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 80% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 84% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 98% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 98% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 98% 입니다.',
#  '만족도 68% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 82% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 74% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 82% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 82% 입니다.',
#  '만족도 66% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 100% 입니다.']

# %% [markdown]
# # 데이터 프레임으로 저장하고 Excel 파일로 저장하기

# %%
import pandas as pd

gmarket_selenium_df = pd.DataFrame([title_list, price_list, star_list]).T

# %%
gmarket_selenium_df
# Out:
#                                                  0       1              2
# 0             초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기  29,900
# 1                       쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기  14,900
# 2               1+1 초특가 무선 선풍기 휴대용 손 선풍기 미니 손풍기 힐템  34,900
# 3               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45,900   만족도 76% 입니다.
# 4   비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh  29,900   만족도 90% 입니다.
# ..                                             ...     ...            ...
# 92             무선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (화이트)  16,800   만족도 90% 입니다.
# 93            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33,060   만족도 82% 입니다.
# 94                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22,500   만족도 66% 입니다.
# 95             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46,800   만족도 94% 입니다.
# 96                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24,800  만족도 100% 입니다.
#
# [97 rows x 3 columns]

# %%
gmarket_selenium_df.columns = ['상품명', '판매가', '만족도']

# %%
gmarket_selenium_df
# Out:
#                                                상품명     판매가            만족도
# 0             초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기  29,900
# 1                       쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기  14,900
# 2               1+1 초특가 무선 선풍기 휴대용 손 선풍기 미니 손풍기 힐템  34,900
# 3               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45,900   만족도 76% 입니다.
# 4   비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh  29,900   만족도 90% 입니다.
# ..                                             ...     ...            ...
# 92             무선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (화이트)  16,800   만족도 90% 입니다.
# 93            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33,060   만족도 82% 입니다.
# 94                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22,500   만족도 66% 입니다.
# 95             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46,800   만족도 94% 입니다.
# 96                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24,800  만족도 100% 입니다.
#
# [97 rows x 3 columns]

# %%
def extract_comma(x):
    price = int(x.replace(",", "")) #replace로 쉼표까지 제거하고 int로 변환
    return price

# %%
gmarket_selenium_df['판매가'] = gmarket_selenium_df['판매가'].apply(extract_comma)

# %%
import re

def extract_stars(x):
    ext = re.findall("\d+%", x)
    #데이터가 빈 경우가 있으므로 try, except문 사용
    try:
        stars = int(ext[0].replace('%', "")) #%를 제거한 뒤 int로 변환
    except:
        pass
    return stars if ext else None #데이터가 있을 경우 stars를 반환, 아닐 경우 None을 반환

# %%
gmarket_selenium_df['만족도'] = gmarket_selenium_df['만족도'].apply(extract_stars)

# %%
gmarket_selenium_df
# Out:
#                                                상품명    판매가    만족도
# 0             초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기  29900    NaN
# 1                       쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기  14900    NaN
# 2               1+1 초특가 무선 선풍기 휴대용 손 선풍기 미니 손풍기 힐템  34900    NaN
# 3               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45900   76.0
# 4   비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh  29900   90.0
# ..                                             ...    ...    ...
# 92             무선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (화이트)  16800   90.0
# 93            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33060   82.0
# 94                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22500   66.0
# 95             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46800   94.0
# 96                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24800  100.0
#
# [97 rows x 3 columns]

# %%
gmarket_selenium_df = gmarket_selenium_df.dropna().reset_index().iloc[:, 1:]

# %%
gmarket_selenium_df
# Out:
#                                                상품명    판매가    만족도
# 0               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45900   76.0
# 1   비즈 펠티어 냉각판 에어컨 휴대용 손선풍기 BZ-FH40 대용량배터리 4000mAh  29900   90.0
# 2    이지마켓 초강력미니선풍기 미니 손선풍기 에어컨손풍기 얼음이 내손안에 핸디써큘레이터  29900   94.0
# 3                          휴대용 냉각 선풍기 쿨링 핸디팬 다크그레이  27900   88.0
# 4                 LOOC 룩 휴대용 선풍기 미니 손 핸디형 손풍기 - 블랙  15900   94.0
# ..                                             ...    ...    ...
# 89             무선 휴대용 선풍기 MONO-4TFLED 미니 탁상용 (화이트)  16800   90.0
# 90            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33060   82.0
# 91                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22500   66.0
# 92             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46800   94.0
# 93                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24800  100.0
#
# [94 rows x 3 columns]

# %%
gmarket_selenium_df.to_excel('gmarket_handfan_stars.xlsx')

# %% [markdown]
# # 과제 (100점)

# %% [markdown]
# #### 본인이 관심 있는 키워드에 대해서 해당 크롤링을 반복해서 수행하시오. 데이터를 수집하여 excel 파일로 저장하시오.

# %%
#1. 필요한 라이브러리 import 하기 (10점)
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# %%
#2. 본인이 관심 있는 키워드에 대해서 크롤링을 수행하고 상품명, 가격, 별점 정보 저장하기 (40점)
driver = webdriver.Chrome()
driver.get('https://www.gmarket.co.kr')

search_box = driver.find_element(By.NAME, 'keyword')

# 검색어를 입력하고, Enter 키를 눌러 검색을 실행합니다.
search_box.send_keys('손풍기')
search_box.send_keys(Keys.RETURN)

# 결과 페이지가 로드될 때까지 잠시 기다립니다.
driver.implicitly_wait(3)

title_list = []
price_list = []
star_list = []


search_results = driver.find_elements(By.CSS_SELECTOR, 'div.box__information')

for result in search_results:
    #만족도가 없을 수도 있기에 try except문을 활용
    try:
        title_element = result.find_element(By.CSS_SELECTOR, 'span.text__item')
        price_element = result.find_element(By.CSS_SELECTOR, 'div.box__price-seller > strong')
        star_element = result.find_element(By.CSS_SELECTOR, 'span.image__awards-points > span')
        title_list.append(title_element.text)
        price_list.append(price_element.text)
        star_list.append(star_element.text)
    except:
        pass
driver.quit()

# %%
title_list
# Out:
# ['초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기',
#  '휴대용 선풍기 냉풍기 무선 저소음 각도조절 미니 써큘레이터',
#  '휴대용선풍기 휴대용목걸이 미니 손선풍기 RX-8820',
#  'C.ONE 목에거는 휴대용선풍기 넥선풍기 NAVY',
#  '슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200',
#  '이지마켓 초강력미니선풍기 미니 손선풍기 에어컨손풍기 얼음이 내손안에 핸디써큘레이터',
#  'LOOC 룩 휴대용 선풍기 미니 손 핸디형 손풍기 - 블랙',
#  '휴대용 아이스 냉각 미니 손선풍기 딥브라운',
#  '급속냉각 각도조절 핸디선풍기 휴대용 냉각손선풍기',
#  '윈드프로 휴대용 미니 선풍기 무선 목걸이 탁상용 손선풍기 사무실 책상용 무소음 저소음 USB 손풍기 소형',
#  '머레이 3초 급속냉각 각도조절 에어컨 핸디선풍기 cool-10 (화이트/네이비) 미니 휴대용 에어컨 선풍기',
#  '휴대용 쿨링마사지 급속냉각 에어컨 휴대용 손 선풍기 IW-C500 핑크',
#  '휴대용 선풍기 미니 핸디 6단계 IW-F901 화이트',
#  'BLDC모터 미니 손 핸디 휴대용 선풍기 손풍기 USB C타입',
#  '쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기',
#  '오아 반디팬 미니 무선 휴대용 초경량 저소음 핸디 손 선풍기',
#  '초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기',
#  '핸드팬 대용량 2600mAh 충전식 휴대용선풍기 화이트',
#  '오아 반디팬 미니 무선 휴대용 초경량 저소음 핸디 손 선풍기',
#  '코어팬시 미니 휴대용 선풍기 무소음 목걸이형 그린 4800mAh',
#  '쁘띠팬 미니 무선 휴대용 저소음 핸디 손 선풍기',
#  '초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍
+1 휴대용 집게 선풍기 6인치대형팬 BLDC 탁상용 유모차선풍기 OEF-6FAN',
#  '휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙',
#  '휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린',
#  '무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1',
#  '엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W']

# %%
price_list
# Out:
# ['29,900',
#  '37,900',
#  '17,300',
#  '29,900',
#  '45,900',
#  '29,900',
#  '15,900',
#  '29,900',
#  '37,900',
#  '22,900',
#  '37,900',
#  '29,900',
#  '23,650',
#  '13,000',
#  '14,900',
#  '14,900',
#  '29,900',
#  '14,000',
#  '14,900',
#  '22,680',
#  '14,900',
#  '29,900',
#  '34,900',
#  '29,900',
#  '26,800',
#  '26,800',
#  '39,900',
#  '26,900',
#  '46,900',
#  '24,900',
#  '118,990',
#  '26,900',
#  '29,900',
#  '36,600',
#  '39,900',
#  '36,600',
#  '29,900',
#  '21,900',
#  '26,900',
#  '17,810',
#  '36,600',
#  '26,800',
#  '24,900',
#  '22,680',
#  '19,900',
#  '27,900',
#  '118,990',
#  '26,900',
#  '26,800',
#  '26,800',
#  '37,900',
#  '34,900',
#  '16,900',
#  '29,900',
#  '29,900',
#  '148,000',
#  '28,410',
#  '26,500',
#  '29,900',
#  '139,000',
#  '24,900',
#  '37,900',
#  '15,900',
#  '43,900',
#  '49,900',
#  '35,900',
#  '89,000',
#  '26,900',
#  '17,900',
#  '149,000',
#  '38,900',
#  '15,900',
#  '44,900',
#  '15,900',
#  '27,310',
#  '39,800',
#  '25,900',
#  '18,910',
#  '36,900',
#  '29,900',
#  '19,900',
#  '16,800',
#  '29,800',
#  '26,900',
#  '69,000',
#  '13,000',
#  '24,610',
#  '28,900',
#  '32,900',
#  '59,800',
#  '22,900',
#  '27,000',
#  '26,500',
#  '16,800',
#  '27,900',
#  '33,060',
#  '22,500',
#  '46,800',
#  '24,800']

# %%
star_list
# Out:
# ['',
#  '',
#  '',
#  '만족도 92% 입니다.',
#  '만족도 76% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 70% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 80% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 98% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 84% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 98% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 98% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 82% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 74% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 88% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 86% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 96% 입니다.',
#  '만족도 100% 입니다.',
#  '만족도 82% 입니다.',
#  '만족도 90% 입니다.',
#  '만족도 92% 입니다.',
#  '만족도 82% 입니다.',
#  '만족도 66% 입니다.',
#  '만족도 94% 입니다.',
#  '만족도 100% 입니다.']

# %%
#3. 적절히 데이터 전처리를 하여 DataFrame 객체로 만들고 Excel 파일로 저장하기 (50점)
#이때, DataFrame의 열은 "상품명, 판매가, 만족도"로 구성되어야 함.
shampoo_df = pd.DataFrame([title_list,price_list,star_list],index=['상품명','판매가','만족도']).T
shampoo_df
# Out:
#                                                상품명     판매가            만족도
# 0             초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기  29,900
# 1                 휴대용 선풍기 냉풍기 무선 저소음 각도조절 미니 써큘레이터  37,900
# 2                    휴대용선풍기 휴대용목걸이 미니 손선풍기 RX-8820  17,300
# 3                      C.ONE 목에거는 휴대용선풍기 넥선풍기 NAVY  29,900   만족도 92% 입니다.
# 4               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45,900   만족도 76% 입니다.
# ..                                             ...     ...            ...
# 94  1+1 휴대용 집게 선풍기 6인치대형팬 BLDC 탁상용 유모차선풍기 OEF-6FAN  27,900   만족도 92% 입니다.
# 95            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33,060   만족도 82% 입니다.
# 96                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22,500   만족도 66% 입니다.
# 97             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46,800   만족도 94% 입니다.
# 98                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24,800  만족도 100% 입니다.
#
# [99 rows x 3 columns]

# %%
def comma(text):
    try:
        text_ = int(text.replace(',',''))
    except:
        pass
    return text_

# %%
shampoo_df['판매가'] = shampoo_df['판매가'].apply(comma)
shampoo_df
# Out:
#                                                상품명    판매가            만족도
# 0             초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기  29900
# 1                 휴대용 선풍기 냉풍기 무선 저소음 각도조절 미니 써큘레이터  37900
# 2                    휴대용선풍기 휴대용목걸이 미니 손선풍기 RX-8820  17300
# 3                      C.ONE 목에거는 휴대용선풍기 넥선풍기 NAVY  29900   만족도 92% 입니다.
# 4               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45900   만족도 76% 입니다.
# ..                                             ...    ...            ...
# 94  1+1 휴대용 집게 선풍기 6인치대형팬 BLDC 탁상용 유모차선풍기 OEF-6FAN  27900   만족도 92% 입니다.
# 95            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33060   만족도 82% 입니다.
# 96                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22500   만족도 66% 입니다.
# 97             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46800   만족도 94% 입니다.
# 98                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24800  만족도 100% 입니다.
#
# [99 rows x 3 columns]

# %%
def fill_na(x):
    ext = re.findall('\d+',x)
    try:
        star = int(ext[0])
    except:
        pass
    return star if ext else None

# %%
shampoo_df['만족도'] = shampoo_df['만족도'].apply(fill_na)
shampoo_df
# Out:
#                                                상품명    판매가    만족도
# 0             초경량 1+1 미소양품 프리미엄 소형 미니 휴대용 핸디 손 선풍기  29900    NaN
# 1                 휴대용 선풍기 냉풍기 무선 저소음 각도조절 미니 써큘레이터  37900    NaN
# 2                    휴대용선풍기 휴대용목걸이 미니 손선풍기 RX-8820  17300    NaN
# 3                      C.ONE 목에거는 휴대용선풍기 넥선풍기 NAVY  29900   92.0
# 4               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45900   76.0
# ..                                             ...    ...    ...
# 94  1+1 휴대용 집게 선풍기 6인치대형팬 BLDC 탁상용 유모차선풍기 OEF-6FAN  27900   92.0
# 95            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33060   82.0
# 96                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22500   66.0
# 97             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46800   94.0
# 98                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24800  100.0
#
# [99 rows x 3 columns]

# %%
shampoo_df.dropna(inplace=True)

# %%
shampoo_df = shampoo_df.reset_index().iloc[:,1:]
shampoo_df
# Out:
#                                                상품명    판매가    만족도
# 0                      C.ONE 목에거는 휴대용선풍기 넥선풍기 NAVY  29900   92.0
# 1               슈틸루스터 에어컨 선풍기 올리브 season2 ST-AF200  45900   76.0
# 2    이지마켓 초강력미니선풍기 미니 손선풍기 에어컨손풍기 얼음이 내손안에 핸디써큘레이터  29900   94.0
# 3                 LOOC 룩 휴대용 선풍기 미니 손 핸디형 손풍기 - 블랙  15900   94.0
# 4                          휴대용 아이스 냉각 미니 손선풍기 딥브라운  29900   86.0
# ..                                             ...    ...    ...
# 91  1+1 휴대용 집게 선풍기 6인치대형팬 BLDC 탁상용 유모차선풍기 OEF-6FAN  27900   92.0
# 92            휴대용 넥밴드 선풍기 넥 목 목걸이 유팬 목풍기 BI-NF8 블랙  33060   82.0
# 93                    휴대용 넥밴드 선풍기 충전식 넥선풍기 A206 그린  22500   66.0
# 94             무선 휴대용 선풍기 TS-8DF45(화이트) 미니 탁상용 1+1  46800   94.0
# 95                   엑스 포켓 넥밴드 목걸이 휴대용선풍기 SX-NF21W  24800  100.0
#
# [96 rows x 3 columns]

# %%
shampoo_df.to_excel('shampoo_DataFrame.xlsx')
